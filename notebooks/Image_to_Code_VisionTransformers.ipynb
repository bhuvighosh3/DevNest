# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 58.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 37.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 116.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 95.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 32.9 MB/s eta 0:00:00
# ...

# %%
# !pip install torch

# %%
# Web links Handler
import requests

# Backend
import torch

# Image Processing
from PIL import Image

# Transformer and pre-trained Model
from transformers import VisionEncoderDecoderModel, ViTImageProcessor, GPT2TokenizerFast

# Managing loading processing
from tqdm import tqdm

# Assign available GPU
device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# ### Final code:

# %%
# !pip install openai==0.28

# %%
import openai

# %%
import requests
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration
from IPython.display import display
from google.colab import files

# Load pre-trained model and processor
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-large")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-large")

# %%
# Upload image
uploaded = files.upload()

# Check if an image is uploaded
if len(uploaded) == 0:
    print("No image uploaded.")
else:
    # Get the uploaded image
    img_path = list(uploaded.keys())[0]
    raw_image = Image.open(img_path).convert('RGB')
    display(raw_image)  # Display the uploaded image
    text = "a photography of"
    inputs = processor(raw_image,return_tensors="pt")
    out = model.generate(**inputs)
    caption = processor.decode(out[0], skip_special_tokens=True)
    print("Conditional Image Caption:", caption)

# %%
openai.api_key='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'
prompt = f"{caption}.This is the description according to which you have to write the specifications that can be considered while making a reaact component from this."
response = openai.Completion.create(
    model="text-davinci-003",
    prompt=prompt,
    temperature=0.7,
    max_tokens=150,
)
generated_description = response['choices'][0]['text']
print(generated_description)
# Out:
# Specifications:
#
# • A purple background color
# • Login form fields for username and password
# • Login button
# • Text fields with appropriate font size and font type
# • Input validation for username and password fields
# • Ability to customize the background color and form fields
# • Ability to add additional features like a “Forgot Password” link, social media login, etc.

# %%
prompt = f"Generate the code for the described react function based component component.It should have react & css code too.Name the css file & import it.Do not include the image in the code {generated_description}"
response = openai.Completion.create(
    model="text-davinci-003",
    prompt=prompt,
    temperature=0.7,
    max_tokens=1100,
)
generated_desc= response['choices'][0]['text']
print(generated_desc)
# Out:
# React Function Component Code:
#
# import React from 'react';
# import './LoginForm.css';
#
# const LoginForm = () => {
#   const [username, setUsername] = React.useState('');
#   const [password, setPassword] = React.useState('');
#   const [backgroundColor, setBackgroundColor] = React.useState('purple');
#   const [inputValidation, setInputValidation] = React.useState(false);
#
#   const handleUsernameChange = (event) => {
#     setUsername(event.target.value);
#     setInputValidation(false);
#   };
#
#   const handlePasswordChange = (event) => {
#     setPassword(event.target.value);
#     setInputValidation(false);
#   };
#
#   const handleSubmit = (event) => {
#     event.preventDefault();
#     if (!username || !password) {
#       setInputValidation(true);
#       return;
#     }
#   };
#
#   const handleBackgroundColorChange = (event) => {
#     setBackgroundColor(event.target.value);
#   };
#
#   return (
#     <div className="login-form" style={{ backgroundColor }}>
# ...
